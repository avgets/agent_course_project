# %%
from marker.converters.table import TableConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered
import json
from pathlib import Path

pdf_path = "input.pdf"
out_dir = Path("output")
out_dir.mkdir(exist_ok=True)

converter = TableConverter(
    artifact_dict=create_model_dict(),
)

rendered = converter(pdf_path)

# Текстовое представление таблиц (обычно markdown/html-подобный вывод)
text, metadata, images = text_from_rendered(rendered)

(out_dir / "tables.md").write_text(text, encoding="utf-8")
(out_dir / "metadata.json").write_text(
    json.dumps(metadata, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print("Done")
# Out:
# ...
# Recognizing Text: 100%|██████████| 591/591 [2:02:57<00:00, 12.48s/it]
# Done

# %%
from marker.converters.table import TableConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered
from marker.config.parser import ConfigParser
import json
from pathlib import Path

pdf_path = "input.pdf"
out_dir = Path("output")
out_dir.mkdir(exist_ok=True)

config_parser = ConfigParser({
    "output_format": "markdown",
    "ocr_engine": "ocrmypdf",   # переключаем OCR на Tesseract через OCRmyPDF
})

converter = TableConverter(
    artifact_dict=create_model_dict(),
    config=config_parser.generate_config_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service(),
)

rendered = converter(pdf_path)

text, metadata, images = text_from_rendered(rendered)

(out_dir / "tables.md").write_text(text, encoding="utf-8")
(out_dir / "metadata.json").write_text(
    json.dumps(metadata, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print("Done")
# Out:
# Recognizing Layout:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      12 config_parser = ConfigParser({
#      13     "output_format": "markdown",
#      14     "ocr_engine": "ocrmypdf",   # переключаем OCR на Tesseract через OCRmyPDF
#      15 })
#      17 converter = TableConverter(
#      18     artifact_dict=create_model_dict(),
#      19     config=config_parser.generate_config_dict(),
#    (...)
#      22     llm_service=config_parser.get_llm_service(),
#      23 )
# ---> 25 rendered = converter(pdf_path)
#      27 text, metadata, images = text_from_rendered(rendered)
#      29 (out_dir / "tables.md").write_text(text, encoding="utf-8")
#
# File c:\Users\GaV\AppData\Local\Programs\Python\Python312\Lib\site-packages\marker\converters\table.py:53, in TableConverter.__call__(self, filepath)
# ...

# %%
import os
import json
from pathlib import Path

from marker.converters.table import TableConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered
from marker.config.parser import ConfigParser


DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")

pdf_path = "input.pdf"
out_dir = Path("output")
out_dir.mkdir(exist_ok=True)

config = {
    "output_format": "markdown",
    "ocr_engine": "ocrmypdf",

    # Включаем использование LLM
    "use_llm": True,

    # Marker умеет OpenAI-compatible сервис
    "llm_service": "marker.services.openai.OpenAIService",

    # DeepSeek как OpenAI-compatible endpoint
    "openai_api_key": DEEPSEEK_API_KEY,
    "openai_base_url": "https://api.deepseek.com",
    "openai_model": "deepseek-v4-pro",

    # Опционально
    "debug": False,
}

config_parser = ConfigParser(config)

converter = TableConverter(
    artifact_dict=create_model_dict(),
    config=config_parser.generate_config_dict(),
    processor_list=config_parser.get_processors(),
    renderer=config_parser.get_renderer(),
    llm_service=config_parser.get_llm_service(),
)

rendered = converter(pdf_path)

text, metadata, images = text_from_rendered(rendered)

(out_dir / "tables.md").write_text(text, encoding="utf-8")
(out_dir / "metadata.json").write_text(
    json.dumps(metadata, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print("Done")
